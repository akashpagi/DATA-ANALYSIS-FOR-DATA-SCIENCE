# %% [markdown]
# ### SESSION 28 - DATA ASSESSING & CLEANING
#
# #### **DATA ASSESSING:**
# - In this step, the data is to be understood more deeply, Before implementing methods to clean it, you will definitely need to have a better idea about what the data is about.
# ms a table forms a table*

# %% [markdown]
# **Types of Unclean Data:**
# - There are 2 kinds of unclean data
#
#
# - **Dirty Data (Data with Quality issues):**
#     -  Dirty data, also known as low quality data.
#     -  Low quality data has content issues.
#         - Duplicated data
#         - Missing Data
#         - Corrupt Data (not able to load)
#         - Inaccurate Data
# ![image.png](attachment:0cd11380-ff16-4456-9b88-c9236cfeeade.png)
#
# Above example dirty data to tidy data
#
# - **Messy Data (Data with tidiness issues):**
#     - Messy data, also known as untidy data.
#     - Untidy data has structural issues.
#     - Here are three interrelated rules that make a dataset tidy:
#         - Each variable must have its own column; each column is a variable.
#         - Each observation must have its own row; each row is an observation.
#         - Each value must have its own cell; each cell is a single value.
# ![image.png](attachment:5ad0e714-45b6-4ee8-ba3c-2c123059da96.png)
#
# ![image.png](attachment:beff1305-09bc-4372-bedf-233c138dd2bf.png)
# In the given example, both bp1 and bp2 represent measurements. However, they each occupy an additional column, contributing to messy data. To address this data cleanliness issue, we aim to create tidy data.
